# %% [markdown]
# # Mall Customers

# %% [markdown]
# ## Describes of columns:
# ### CustomerID: Unique ID assigned to the customer
# ### Annual Income (k$): Annual Income of the customee
# ### Gender: Gender of the customer
# ### Age: Age of the customer
# ### Spending Score (1-100): Score assigned by the mall based on customer behavior and spending nature

# %% [markdown]
# - Our Target is Spending Score.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# import plotting
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read Data

# %%
# load dataframe with train labels
df = pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #### check if data has null values or not

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# #### EDA and Data visualization for this Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df[['Spending Score (1-100)','Annual Income (k$)']].describe()
# Out:
#        Spending Score (1-100)  Annual Income (k$)
# count              200.000000          200.000000
# mean                50.200000           60.560000
# std                 25.823522           26.264721
# min                  1.000000           15.000000
# 25%                 34.750000           41.500000
# 50%                 50.000000           61.500000
# 75%                 73.000000           78.000000
# max                 99.000000          137.000000

# %%
plt.figure(figsize=(3, 3))
sns.countplot(df,x='Gender',palette=['#1AACAC','#FACBEA'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# plotting a pie chart
labels = 'Female', 'Male'
female = df[df['Gender'] == 'Female'].Gender.count()
male = df[df['Gender'] == 'Male'].Gender.count()
sizes = [female, male]
explode = (0, 0.1)

fig, ax = plt.subplots(figsize=(3, 3))
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90,colors=['#FACBEA','#1AACAC'])
ax.axis('equal')
ax.set_title('Gender of Customer')

plt.show()

# %% [markdown]
# - Note : female is greater than male .

# %%
plt.figure(figsize=(10, 3))
sns.countplot(df,x='Age')
plt.xticks(rotation = 90);

# %% [markdown]
# - Note: large number of customer has 31 and 35 years, small number of them  has (55,56,64,69) years.

# %%
plt.figure(figsize=(10, 3))
sns.countplot(df,x='Annual Income (k$)')
plt.xticks(rotation = 90);

# %% [markdown]
# - Note : alot of customer his income 54, 78 $

# %%
plt.figure(figsize=(7, 3))
sns.scatterplot(df,x='Age',y='Spending Score (1-100)',hue="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Spending Score (1-100)'>

# %% [markdown]
# - Note : the most customers that spend between (80 -100) are between (30 - 40 )year and customers that are between (60-70) spend (0 -60)

# %%
plt.figure(figsize=(7, 3))
sns.scatterplot(df,x='Annual Income (k$)',y='Spending Score (1-100)',hue="Age",palette="Blues",size="Age")
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %% [markdown]
# - Note : most customers between (60 -70)has income between (40 - 65)and spend between(40 - 60)$.

# %%
plt.figure(figsize=(7, 3))
sns.scatterplot(df,x='Annual Income (k$)',y='Spending Score (1-100)',hue="Gender",palette="Greens",size="Age")
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %% [markdown]
# - Note : customer female is greater than male .

# %%
plt.figure(figsize=(7, 3))
sns.scatterplot(df,x='Age',y='Gender',hue="Age",palette="Blues",size="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %% [markdown]
# - Note : alot of male are between (60- 70)year,and female between (63 - 68)years,and less than male

# %% [markdown]
# ## Model

# %%
df.iloc[:, [3, 4]]
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
X = df.iloc[:, [3, 4]].values

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []            ## total distances from the centeriods
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++')
    kmeans.fit(X)
    print('Cost_Function=',kmeans.inertia_,'with', i, 'Clusters')
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cost_Function= 269981.28 with 1 Clusters
# Cost_Function= 181363.59595959593 with 2 Clusters
# Cost_Function= 106348.37306211122 with 3 Clusters
# Cost_Function=
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ## **Thanks**
